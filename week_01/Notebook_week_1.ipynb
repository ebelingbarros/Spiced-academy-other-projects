# %% [markdown]
# # Project Week 1: Creating an animated scatterplot with Python

# %%
#Import libraries
import pandas as pd
import imageio
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: Read in data

# %%
gdppercapitagrowth = pd.read_csv('data/gdp_per_capita_growth.csv', index_col=0)
gdppercapitagrowth
# Out:
#                              1960      1961      1962      1963      1964  \
# Country Name
# Aruba                         NaN       NaN       NaN       NaN       NaN
# Africa Eastern and Southern   NaN -1.439563  4.755908  3.054067  2.767854
# Afghanistan                   NaN       NaN       NaN       NaN       NaN
# Africa Western and Central    NaN -0.183547  1.647202  4.763988  2.965075
# Angola                        NaN       NaN       NaN       NaN       NaN
# ...                           ...       ...       ...       ...       ...
# Kosovo                        NaN       NaN       NaN       NaN       NaN
# Yemen, Rep.                   NaN       NaN       NaN       NaN       NaN
# South Africa                  NaN  1.328134  3.570381  4.707660  5.237069
# Zambia                        NaN -1.635258 -5.371127  0.215682  8.873040
# Zimbabwe                      NaN  2.821534 -1.934893  2.697117 -4.403385
#
#                                   1965      1966       1967      1968  \
# Country Name
# Aruba                              NaN       NaN        NaN       NaN
# Africa Eastern and Southern   2.861630  1.345608   3.031530  1.283349
# Afghanistan                        NaN       NaN        NaN       NaN
# Africa Western and Central    1.906585 -3.955568 -11.415693 -0.861484
# Angola                             NaN       NaN        NaN       NaN
# ...                                ...       ...        ...       ...
# Kosovo                             NaN       NaN        NaN       NaN
# Yemen, Rep.                        NaN       NaN        NaN       NaN
# South Africa                  3.448264  1.794717   4.472366  1.491269
# Zambia                       13.143425 -8.429576   4.625624 -1.877708
# Zimbabwe                      1.430334 -1.818169   4.819220 -1.374107
#
#                                   1969  ...       2011       2012      2013  \
# Country Name                            ...
# Aruba                              NaN  ...   3.055788  -1.865105  3.592223
# Africa Eastern and Southern   2.349179  ...   1.406598   0.464708  1.662889
# Afghanistan                        NaN  ...  -2.681061   8.974865  1.974166
# Africa Western and Central   12.474214  ...   2.169496   2.441335  2.995340
# Angola                             NaN  ...  -0.220843   4.706519  1.291994
# ...                                ...  ...        ...        ...       ...
# Kosovo                             NaN  ...   3.484180   1.893324  2.815002
# Yemen, Rep.                        NaN  ... -15.107919  -0.391864  2.014175
# South Africa                  2.017430  ...   1.721528   0.609713  0.854081
# Zambia                       -3.559056  ...   2.423884   4.310199  1.809749
# Zimbabwe                      8.701580  ...  12.452840  14.701077  0.192474
#
#                                  2014       2015       2016      2017  \
# Country Name
# Aruba                       -0.290534   5.129657   1.587869  1.519821
# Africa Eastern and Southern  1.304635   0.029830  -0.688992  0.137681
# Afghanistan                 -0.665291  -1.622857  -0.541416  0.064764
# Africa Western and Central   3.005480  -0.003081  -2.659707 -0.540874
# Angola                       1.219881  -2.468737  -5.816188 -3.409983
# ...                               ...        ...        ...       ...
# Kosovo                       1.521315   5.525854   4.693171  3.443607
# Yemen, Rep.                 -2.802862 -29.827145 -11.611137 -7.345180
# South Africa                 0.246658  -0.344982  -1.067897 -0.012345
# Zambia                       1.480580  -0.187950   0.706659  0.494086
# Zimbabwe                     0.596149   0.100575  -0.793105  3.182506
#
#                                  2018      2019      2020
# Country Name
# Aruba                             NaN       NaN       NaN
# Africa Eastern and Southern -0.272526 -0.938984 -6.023658
# Afghanistan                 -1.194900  1.535637 -4.168191
# Africa Western and Central   0.124017  0.451219 -3.545482
# Angola                      -5.162112 -3.795608 -7.079822
# ...                               ...       ...       ...
# Kosovo                       3.461972  5.423383 -6.179988
# Yemen, Rep.                 -1.594564       NaN       NaN
# South Africa                -0.578052 -1.157079 -8.136829
# Zambia                       1.047921 -1.450900 -5.774843
# Zimbabwe                     2.047700 -9.396793 -9.346018
#
# [266 rows x 61 columns]

# %%
industry = pd.read_csv('data/industry_value_added_growth.csv', index_col=0)
industry
# Out:
#                              1960      1961      1962      1963       1964  \
# Country Name
# Aruba                         NaN       NaN       NaN       NaN        NaN
# Africa Eastern and Southern   NaN       NaN       NaN       NaN        NaN
# Afghanistan                   NaN       NaN       NaN       NaN        NaN
# Africa Western and Central    NaN       NaN       NaN       NaN        NaN
# Angola                        NaN       NaN       NaN       NaN        NaN
# ...                           ...       ...       ...       ...        ...
# Kosovo                        NaN       NaN       NaN       NaN        NaN
# Yemen, Rep.                   NaN       NaN       NaN       NaN        NaN
# South Africa                  NaN  4.786935  7.322937  7.522622  10.110524
# Zambia                        NaN       NaN       NaN       NaN        NaN
# Zimbabwe                      NaN       NaN       NaN       NaN        NaN
#
#                                  1965      1966      1967      1968      1969  \
# Country Name
# Aruba                             NaN       NaN       NaN       NaN       NaN
# Africa Eastern and Southern       NaN       NaN       NaN       NaN       NaN
# Afghanistan                       NaN       NaN       NaN       NaN       NaN
# Africa Western and Central        NaN       NaN       NaN       NaN       NaN
# Angola                            NaN       NaN       NaN       NaN       NaN
# ...                               ...       ...       ...       ...       ...
# Kosovo                            NaN       NaN       NaN       NaN       NaN
# Yemen, Rep.                       NaN       NaN       NaN       NaN       NaN
# South Africa                 5.488818  4.269526  2.165239  4.525681  5.052268
# Zambia                            NaN -3.287644  4.697645 -0.620006  6.435727
# Zimbabwe                          NaN       NaN       NaN       NaN       NaN
#
#                              ...       2011       2012      2013      2014  \
# Country Name                 ...
# Aruba                        ...        NaN        NaN       NaN       NaN
# Africa Eastern and Southern  ...   2.347632   0.008194  4.356395  2.025406
# Afghanistan                  ...   9.807670   6.394071  5.060991  2.765781
# Africa Western and Central   ...   7.732533   3.498221  2.552909  5.419896
# Angola                       ...  -1.413862  10.685209  3.199417 -1.619390
# ...                          ...        ...        ...       ...       ...
# Kosovo                       ...   4.147740   6.548670  7.398742 -1.618856
# Yemen, Rep.                  ... -13.242873  -1.589049  6.980025 -3.214742
# South Africa                 ...   1.411877   0.434814  2.174950  0.033482
# Zambia                       ...   4.224763   2.014532  2.612240  3.889571
# Zimbabwe                     ...  17.863829   6.750515  3.249430 -2.483343
#
#                                   2015       2016      2017       2018  \
# Country Name
# Aruba                              NaN        NaN       NaN        NaN
# Africa Eastern and Southern   2.928152   1.453496  2.832917   3.954229
# Afghanistan                   4.171121  -0.765914  9.206792  11.074642
# Africa Western and Central   -1.531209  -5.687487  3.203840   2.092192
# Angola                        7.493699   1.010274 -1.648259  -3.607715
# ...                                ...        ...       ...        ...
# Kosovo                        8.568789   2.547234  4.442302   4.562252
# Yemen, Rep.                 -27.760830 -23.525931 -3.628782  -2.285642
# South Africa                  0.822033  -0.787461  1.086615  -0.132946
# Zambia                        6.810082   5.589369  5.403932   4.638745
# Zimbabwe                      0.042980   1.328086  2.464900   3.168071
#
#                                   2019       2020
# Country Name
# Aruba                              NaN        NaN
# Africa Eastern and Southern  -0.223638  -5.679504
# Afghanistan                   4.848868  -4.219543
# Africa Western and Central    3.336361  -3.618260
# Angola                      -10.683120  -8.383578
# ...                                ...        ...
# Kosovo                        4.616863  -7.257204
# Yemen, Rep.                        NaN        NaN
# South Africa                 -1.547450 -12.018474
# Zambia                       -3.267699   0.634007
# Zimbabwe                           NaN        NaN
#
# [266 rows x 61 columns]

# %%
gdp = pd.read_csv('data/gdp_per_capita.csv', index_col=0)
gdp
# Out:
#                                    1960        1961        1962        1963  \
# Country Name
# Aruba                               NaN         NaN         NaN         NaN
# Africa Eastern and Southern  147.450369  146.853701  156.017929  182.044085
# Afghanistan                   59.773234   59.860900   58.458009   78.706429
# Africa Western and Central   107.963779  113.114697  118.865837  123.478967
# Angola                              NaN         NaN         NaN         NaN
# ...                                 ...         ...         ...         ...
# Kosovo                              NaN         NaN         NaN         NaN
# Yemen, Rep.                         NaN         NaN         NaN         NaN
# South Africa                 443.009920  454.962013  473.011405  511.497364
# Zambia                       232.188565  220.042067  212.578449  213.896759
# Zimbabwe                     278.813847  280.828663  276.688233  277.479715
#
#                                    1964        1965        1966        1967  \
# Country Name
# Aruba                               NaN         NaN         NaN         NaN
# Africa Eastern and Southern  162.169577  180.017301  190.636220  192.126267
# Afghanistan                   82.095307  101.108325  137.594298  160.898434
# Africa Western and Central   131.892939  138.566819  144.368395  128.620051
# Angola                              NaN         NaN         NaN         NaN
# ...                                 ...         ...         ...         ...
# Kosovo                              NaN         NaN         NaN         NaN
# Yemen, Rep.                         NaN         NaN         NaN         NaN
# South Africa                 548.996058  584.704163  621.220543  675.135345
# Zambia                       242.384473  303.281740  343.373670  360.201239
# Zimbabwe                     281.558896  293.308788  277.234532  292.270533
#
#                                    1968        1969  ...          2011  \
# Country Name                                         ...
# Aruba                               NaN         NaN  ...  24985.013920
# Africa Eastern and Southern  203.783404  227.658711  ...   1682.287263
# Afghanistan                  129.108311  129.329760  ...    591.162798
# Africa Western and Central   129.678996  143.757635  ...   1827.518347
# Angola                              NaN         NaN  ...   4615.468219
# ...                                 ...         ...  ...           ...
# Kosovo                              NaN         NaN  ...   3741.875052
# Yemen, Rep.                         NaN         NaN  ...   1374.621401
# South Africa                 711.225742  780.625919  ...   8007.476439
# Zambia                       409.775349  485.872618  ...   1672.907535
# Zimbabwe                     299.398936  341.985387  ...   1093.653409
#
#                                      2012          2013          2014  \
# Country Name
# Aruba                        24712.493260  26441.619940  26893.011510
# Africa Eastern and Southern   1667.992618   1648.867514   1654.314865
# Afghanistan                    641.871438    637.165464    613.856505
# Africa Western and Central    1936.390962   2123.392433   2166.743309
# Angola                        5100.097027   5254.881126   5408.411700
# ...                                   ...           ...           ...
# Kosovo                        3596.804655   3891.266363   4080.330717
# Yemen, Rep.                   1446.536472   1607.152173   1674.002572
# South Africa                  7501.661096   6832.725546   6433.400402
# Zambia                        1763.069442   1878.346811   1762.427817
# Zimbabwe                      1304.968011   1429.998461   1434.896277
#
#                                      2015          2016          2017  \
# Country Name
# Aruba                        28396.908420  28452.170610  29350.805020
# Africa Eastern and Southern   1503.859334   1401.281053   1536.206783
# Afghanistan                    578.466353    509.220101    519.888913
# Africa Western and Central    1886.248158   1666.422406   1606.978332
# Angola                        4166.979833   3506.073128   4095.810057
# ...                                   ...           ...           ...
# Kosovo                        3603.025501   3780.003689   4045.614209
# Yemen, Rep.                   1601.830063   1138.603723    960.528848
# South Africa                  5734.633422   5272.543648   6131.479450
# Zambia                        1338.290927   1280.806543   1535.196574
# Zimbabwe                      1445.069702   1464.588957   1335.665064
#
#                                      2018         2019         2020
# Country Name
# Aruba                        30253.279360          NaN          NaN
# Africa Eastern and Southern   1530.161917  1481.425292  1326.663658
# Afghanistan                    493.756581   507.103392   508.808409
# Africa Western and Central    1695.959215  1772.339155  1714.426800
# Angola                        3289.643995  2809.626088  1895.770869
# ...                                   ...          ...          ...
# Kosovo                        4419.914327  4445.890702  4287.200903
# Yemen, Rep.                    824.117718          NaN          NaN
# South Africa                  6372.605655  6001.401121  5090.715025
# Zambia                        1516.371100  1305.002214  1050.919283
# Zimbabwe                      1352.162653  1156.154864  1128.210711
#
# [266 rows x 61 columns]

# %% [markdown]
# ### Step 2: some preliminary data exploration

# %%
print(gdppercapitagrowth.shape)
# Out:
# (266, 61)

# %%
print(industry.shape)
# Out:
# (266, 61)

# %%
print(gdp.shape)
# Out:
# (266, 61)

# %%
gdppercapitagrowth.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
industry.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
gdp.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
gdppercapitagrowth.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %%
industry.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %%
gdp.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %% [markdown]
# ### Step 3: some preliminary data transformation

# %%
gdppercapitagrowth.columns = gdppercapitagrowth.columns.astype(int)
industry.columns = industry.columns.astype(int)
gdp.columns = gdp.columns.astype(int)

# %%
gdppercapitagrowth.index.name = 'country'

# %%
gdppercapitagrowth = gdppercapitagrowth.reset_index()

# %%
gdppercapitagrowth = gdppercapitagrowth.melt(id_vars='country', var_name='year', value_name='gdppercapitagrowth')

# %%
industry.index.name = 'country'

# %%
industry = industry.reset_index()

# %%
industry = industry.melt(id_vars='country', var_name='year', value_name='industry')

# %%
gdp.index.name = 'country'

# %%
gdp = gdp.reset_index()

# %%
gdp = gdp.melt(id_vars='country', var_name='year', value_name='gdp')

# %% [markdown]
# ### Step 4: merging the dataframes

# %%
df = gdppercapitagrowth.merge(industry)
df
# Out:
#                            country  year  gdppercapitagrowth   industry
# 0                            Aruba  1960                 NaN        NaN
# 1      Africa Eastern and Southern  1960                 NaN        NaN
# 2                      Afghanistan  1960                 NaN        NaN
# 3       Africa Western and Central  1960                 NaN        NaN
# 4                           Angola  1960                 NaN        NaN
# ...                            ...   ...                 ...        ...
# 16221                       Kosovo  2020           -6.179988  -7.257204
# 16222                  Yemen, Rep.  2020                 NaN        NaN
# 16223                 South Africa  2020           -8.136829 -12.018474
# 16224                       Zambia  2020           -5.774843   0.634007
# 16225                     Zimbabwe  2020           -9.346018        NaN
#
# [16226 rows x 4 columns]

# %%
continents = pd.read_csv('data/continents.csv', index_col=0)
continents
# Out:
#                                    Continent
# country
# Aruba                        Central America
# Africa Eastern and Southern                0
# Afghanistan                             Asia
# Africa Western and Central                 0
# Angola                                Africa
# ...                                      ...
# Kosovo                                Europe
# Yemen, Rep.                             Asia
# South Africa                          Africa
# Zambia                                Africa
# Zimbabwe                              Africa
#
# [266 rows x 1 columns]

# %%
df = pd.merge(df, continents, how = "left", on = "country" )
df
# Out:
#                            country  year  gdppercapitagrowth   industry  \
# 0                            Aruba  1960                 NaN        NaN
# 1      Africa Eastern and Southern  1960                 NaN        NaN
# 2                      Afghanistan  1960                 NaN        NaN
# 3       Africa Western and Central  1960                 NaN        NaN
# 4                           Angola  1960                 NaN        NaN
# ...                            ...   ...                 ...        ...
# 16221                       Kosovo  2020           -6.179988  -7.257204
# 16222                  Yemen, Rep.  2020                 NaN        NaN
# 16223                 South Africa  2020           -8.136829 -12.018474
# 16224                       Zambia  2020           -5.774843   0.634007
# 16225                     Zimbabwe  2020           -9.346018        NaN
#
#              Continent
# 0      Central America
# 1                    0
# 2                 Asia
# 3                    0
# 4               Africa
# ...                ...
# 16221           Europe
# 16222             Asia
# 16223           Africa
# 16224           Africa
# 16225           Africa
#
# [16226 rows x 5 columns]

# %%
df = df.reset_index()
gdp = gdp.reset_index()
gdp
# Out:
#        index                      country  year          gdp
# 0          0                        Aruba  1960          NaN
# 1          1  Africa Eastern and Southern  1960   147.450369
# 2          2                  Afghanistan  1960    59.773234
# 3          3   Africa Western and Central  1960   107.963779
# 4          4                       Angola  1960          NaN
# ...      ...                          ...   ...          ...
# 16221  16221                       Kosovo  2020  4287.200903
# 16222  16222                  Yemen, Rep.  2020          NaN
# 16223  16223                 South Africa  2020  5090.715025
# 16224  16224                       Zambia  2020  1050.919283
# 16225  16225                     Zimbabwe  2020  1128.210711
#
# [16226 rows x 4 columns]

# %%
df = pd.merge(df, gdp, how = "outer", on='index')
df
# Out:
#        index                    country_x year_x  gdppercapitagrowth  \
# 0          0                        Aruba   1960                 NaN
# 1          1  Africa Eastern and Southern   1960                 NaN
# 2          2                  Afghanistan   1960                 NaN
# 3          3   Africa Western and Central   1960                 NaN
# 4          4                       Angola   1960                 NaN
# ...      ...                          ...    ...                 ...
# 16221  16221                       Kosovo   2020           -6.179988
# 16222  16222                  Yemen, Rep.   2020                 NaN
# 16223  16223                 South Africa   2020           -8.136829
# 16224  16224                       Zambia   2020           -5.774843
# 16225  16225                     Zimbabwe   2020           -9.346018
#
#         industry        Continent                    country_y year_y  \
# 0            NaN  Central America                        Aruba   1960
# 1            NaN                0  Africa Eastern and Southern   1960
# 2            NaN             Asia                  Afghanistan   1960
# 3            NaN                0   Africa Western and Central   1960
# 4            NaN           Africa                       Angola   1960
# ...          ...              ...                          ...    ...
# 16221  -7.257204           Europe                       Kosovo   2020
# 16222        NaN             Asia                  Yemen, Rep.   2020
# 16223 -12.018474           Africa                 South Africa   2020
# 16224   0.634007           Africa                       Zambia   2020
# 16225        NaN           Africa                     Zimbabwe   2020
#
#                gdp
# 0              NaN
# 1       147.450369
# 2        59.773234
# 3       107.963779
# 4              NaN
# ...            ...
# 16221  4287.200903
# 16222          NaN
# 16223  5090.715025
# 16224  1050.919283
# 16225  1128.210711
#
# [16226 rows x 9 columns]

# %%
# Retrieving different values from "Continent" column
df['Continent'].value_counts()
# Out:
# Africa             3294
# Europe             3294
# 0                  2989
# Asia               2745
# Central America    1830
# Oceania            1159
# South America       732
# North America       183
# Name: Continent, dtype: int64

# %%
indexNames = df[df['Continent'] == "0"].index
df.drop(indexNames, inplace=True)
df.dropna()
df
# Out:
#        index     country_x year_x  gdppercapitagrowth   industry  \
# 0          0         Aruba   1960                 NaN        NaN
# 2          2   Afghanistan   1960                 NaN        NaN
# 4          4        Angola   1960                 NaN        NaN
# 5          5       Albania   1960                 NaN        NaN
# 6          6       Andorra   1960                 NaN        NaN
# ...      ...           ...    ...                 ...        ...
# 16221  16221        Kosovo   2020           -6.179988  -7.257204
# 16222  16222   Yemen, Rep.   2020                 NaN        NaN
# 16223  16223  South Africa   2020           -8.136829 -12.018474
# 16224  16224        Zambia   2020           -5.774843   0.634007
# 16225  16225      Zimbabwe   2020           -9.346018        NaN
#
#              Continent     country_y year_y          gdp
# 0      Central America         Aruba   1960          NaN
# 2                 Asia   Afghanistan   1960    59.773234
# 4               Africa        Angola   1960          NaN
# 5               Europe       Albania   1960          NaN
# 6               Europe       Andorra   1960          NaN
# ...                ...           ...    ...          ...
# 16221           Europe        Kosovo   2020  4287.200903
# 16222             Asia   Yemen, Rep.   2020          NaN
# 16223           Africa  South Africa   2020  5090.715025
# 16224           Africa        Zambia   2020  1050.919283
# 16225           Africa      Zimbabwe   2020  1128.210711
#
# [13237 rows x 9 columns]

# %%
column_a = df["gdppercapitagrowth"]
xmax = column_a.max()
xmin = column_a.min()
column_b = df["industry"]
ymax = column_b.max()
ymin = column_b.min()

# %%
df_subset = df.loc[df['year_x'] == 2000]
sns.scatterplot(x='gdppercapitagrowth', y='industry', 
            data=df_subset, alpha=0.6)
plt.show()

# %% [markdown]
# ### Step 5: creating a version of the visualisation with outliers

# %%
year_list = list(range(1965, 2020))

# %%
for a in (year_list):
        df_subset = df.loc[df['year_x'] == a]
        sns.scatterplot(x='gdppercapitagrowth', y='industry', size='gdp', hue='gdp', data=df_subset, alpha=0.8, sizes=(60, 200), legend = False)
        plt.axis((xmin, xmax, ymin, ymax))
        plt.xlabel("GDP per capita growth")
        plt.ylabel("Industrial value added growth")
        plt.title(str(a)) 
        plt.savefig('growth_'+str(a)+'.png', dpi=300)
        plt.close()

images = []

for a in year_list:
    filename = 'growth_{}.png'.format(a)
    images.append(imageio.imread(filename))

imageio.mimsave('output1.gif', images, fps=0.9)

# %% [markdown]
# <img width="60%" height="60%" align="left" src="output1.gif">

# %% [markdown]
# ### Step 6: creating a version of the visualisation without outliers

# %%
for a in (year_list):
        df_subset = df.loc[df['year_x'] == a]
        sns.scatterplot(x='gdppercapitagrowth', y='industry', size='gdp', sizes=(60, 200),
        data=df_subset, alpha=0.75, hue='gdp', legend = False)
        plt.axis((-15, 20, -15, 20))
        plt.xlabel("GDP per capita growth")
        plt.ylabel("Industrial value added growth")
        plt.title(str(a)) 
        plt.savefig('growthb_'+str(a)+'.png', dpi=300)
        plt.close()

images = []

for a in year_list:
    filename = 'growthb_{}.png'.format(a)
    images.append(imageio.imread(filename))

imageio.mimsave('output2.gif', images, fps=0.9)

# %% [markdown]
# <img width="60%" height="60%" align="left" src="output2.gif">

# %% [markdown]
# ### Step 7: creating a version of the visualisation with selected continents are hues

# %%
df['continents'] = ""
df.loc[df['Continent'] == "Asia", "continents"] = "Asia"
df.loc[df['Continent'] == "South America", "continents"] = "South America"

colors = ["#c0c0c0","#ff6600",'#0080ff']

for a in (year_list):
        df_subset = df.loc[df['year_x'] == a]
        g = sns.scatterplot(x='gdppercapitagrowth', y='industry', sizes=(50,1500), size="gdp", palette=colors,
        data=df_subset, alpha=0.6, hue='continents', legend="brief")
        h,l = g.get_legend_handles_labels()
        plt.axis((-20, 20, -20, 20))
        plt.xlabel("GDP per capita growth")
        plt.ylabel("Industrial value added growth")
        sns.despine()
        plt.legend(h[0:3],l[0:3], fontsize=8, loc='lower right', bbox_to_anchor=(1, 0.1))
        plt.text(0.5, -19, '*the larger the bubble, the larger the GDP per capita',
        verticalalignment='bottom', horizontalalignment='center', color='black', fontsize=6)
        plt.text(-17.5, 19, str(a),
        verticalalignment='top', horizontalalignment='left', color='grey', fontsize=10)
        plt.title("Does industrial growth drive GDP per capita growth?") 
        plt.savefig('growthc_'+str(a)+'.png', dpi=300)
        plt.close()
      
images = []

for a in year_list:
    filename = 'growthc_{}.png'.format(a)
    images.append(imageio.imread(filename))

imageio.mimsave('output3.gif', images, fps=1.2)

# %% [markdown]
# <img width="80%" height="80%" align="left" src="output3.gif">
